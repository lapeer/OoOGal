# %%
from OoOGal.OoOGal import * 
from OoOGal.MAST import *

# %%
galaxy_name = 'M51'
galaxy = Galaxy(name = galaxy_name)
    

mast_results = do_query_mast(galaxy)

# %%
print(mast_results)
# Out:
# instrument    filters     PID
# ---------- ------------- -----
#     ACS    CLEAR1L;F435W 10452
#     ACS    CLEAR1L;F435W 11675
#     ACS    CLEAR1L;F435W 13433
#     ACS    CLEAR1L;F814W 10452
#     ACS    CLEAR1L;F814W 11675
#     ACS    CLEAR1L;F814W 13433
#     ACS    CLEAR1L;F814W 14704
#     ACS    CLEAR1L;F814W 15645
#     ACS    CLEAR1L;F814W 16508
#     ACS    CLEAR1S;F220W 10182
#        ...           ...   ...
#     WFPC2          F606W 11229
#     WFPC2          F656N  5123
#     WFPC2          F656N  7375
#     WFPC2          F675W  5777
#     WFPC2          F675W  7375
#     WFPC2          F675W 10877
#     WFPC2          F814W  5777
#     WFPC2          F814W  7375
#     WFPC2          F814W  9073
#     WFPC2          F814W 11229
# Length = 164 rows
